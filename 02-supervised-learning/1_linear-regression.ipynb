# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
from pathlib import Path

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/insurance.csv')

# %%
df = data.copy()
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
numeric_columns = ['age','bmi','children','charges']

# %%
numeric_columns
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],kde=True)

# %%
sns.countplot(x=df['children'])
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x=df['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Cleaning and preprocessing

# %%
df_cleaned = df.copy()

# %%
df_cleaned.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_cleaned.shape
# Out:
# (1338, 7)

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.shape
# Out:
# (1337, 7)

# %%
df_cleaned.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_cleaned.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df_cleaned['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
df_cleaned['sex'] = df_cleaned['sex'].map({'male':0,'female':1})

# %%
df_cleaned['sex'].value_counts()
# Out:
# sex
# 0    675
# 1    662
# Name: count, dtype: int64

# %%
df_cleaned.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    1  27.900         0    yes  southwest  16884.92400
# 1   18    0  33.770         1     no  southeast   1725.55230
# 2   28    0  33.000         3     no  southeast   4449.46200
# 3   33    0  22.705         0     no  northwest  21984.47061
# 4   32    0  28.880         0     no  northwest   3866.85520

# %%
df_cleaned['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
df_cleaned['smoker'] = df_cleaned['smoker'].map({'yes':1,'no':0})

# %%
df_cleaned['smoker'].value_counts()
# Out:
# smoker
# 0    1063
# 1     274
# Name: count, dtype: int64

# %%
df_cleaned.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    1  27.900         0       1  southwest  16884.92400
# 1   18    0  33.770         1       0  southeast   1725.55230
# 2   28    0  33.000         3       0  southeast   4449.46200
# 3   33    0  22.705         0       0  northwest  21984.47061
# 4   32    0  28.880         0       0  northwest   3866.85520

# %%
df_cleaned.rename(columns={
    'sex':'is_female',
    'smoker':'is_smoker'
},inplace=True)

# %%
df_cleaned.head()
# Out:
#    age  is_female     bmi  children  is_smoker     region      charges
# 0   19          1  27.900         0          1  southwest  16884.92400
# 1   18          0  33.770         1          0  southeast   1725.55230
# 2   28          0  33.000         3          0  southeast   4449.46200
# 3   33          0  22.705         0          0  northwest  21984.47061
# 4   32          0  28.880         0          0  northwest   3866.85520

# %%
df_cleaned['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
df_cleaned = pd.get_dummies(df_cleaned,columns=['region'],drop_first=True)

# %%
df_cleaned.head()
# Out:
#    age  is_female     bmi  children  is_smoker      charges  region_northwest  \
# 0   19          1  27.900         0          1  16884.92400             False
# 1   18          0  33.770         1          0   1725.55230             False
# 2   28          0  33.000         3          0   4449.46200             False
# 3   33          0  22.705         0          0  21984.47061              True
# 4   32          0  28.880         0          0   3866.85520              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
df_cleaned = df_cleaned.astype(int)

# %%
df_cleaned
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1333   50          0   30         3          0    10600                 1
# 1334   18          1   31         0          0     2205                 0
# 1335   18          1   36         0          0     1629                 0
# 1336   21          1   25         0          0     2007                 0
# 1337   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1337 rows x 9 columns]

# %% [markdown]
# ## Feature Engineering and Extraction

# %%
sns.histplot(df_cleaned['bmi'])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
df_cleaned['bmi_category'] = pd.cut(
    df_cleaned['bmi'],
    bins=[0, 18.5, 24.9, 29.9, float('inf')],
    labels=['Underweight', 'Normal', 'Overweight', 'Obese'],
)

# %%
df_cleaned
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1333   50          0   30         3          0    10600                 1
# 1334   18          1   31         0          0     2205                 0
# 1335   18          1   36         0          0     1629                 0
# 1336   21          1   25         0          0     2007                 0
# 1337   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest bmi_category
# 0                    0                 1   Overweight
# 1                    1                 0        Obese
# 2                    1                 0        Obese
# 3                    0                 0       Normal
# 4                    0                 0   Overweight
# ...                ...               ...          ...
# 1333                 0                 0        Obese
# 1334                 0                 0        Obese
# 1335                 1                 0        Obese
# 1336                 0                 1   Overweight
# 1337                 0                 0   Overweight
#
# [1337 rows x 10 columns]

# %%
df_cleaned = pd.get_dummies(df_cleaned,columns = ['bmi_category'],drop_first=True)

# %%
df_cleaned = df_cleaned.astype(int)

# %%
df_cleaned.head()
# Out:
#    age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0   19          1   27         0          1    16884                 0
# 1   18          0   33         1          0     1725                 0
# 2   28          0   33         3          0     4449                 0
# 3   33          0   22         0          0    21984                 1
# 4   32          0   28         0          0     3866                 1
#
#    region_southeast  region_southwest  bmi_category_Normal  \
# 0                 0                 1                    0
# 1                 1                 0                    0
# 2                 1                 0                    0
# 3                 0                 0                    1
# 4                 0                 0                    0
#
#    bmi_category_Overweight  bmi_category_Obese
# 0                        1                   0
# 1                        0                   1
# 2                        0                   1
# 3                        0                   0
# 4                        1                   0

# %%
df_cleaned.columns
# Out:
# Index(['age', 'is_female', 'bmi', 'children', 'is_smoker', 'charges',
#        'region_northwest', 'region_southeast', 'region_southwest',
#        'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

cols = ['age','bmi','children']
scaler = StandardScaler()

# %%
df_cleaned[cols] = scaler.fit_transform(df_cleaned[cols])

# %%
df_cleaned.head()
# Out:
#         age  is_female       bmi  children  is_smoker  charges  \
# 0 -1.440418          1 -0.517949 -0.909234          1    16884
# 1 -1.511647          0  0.462463 -0.079442          0     1725
# 2 -0.799350          0  0.462463  1.580143          0     4449
# 3 -0.443201          0 -1.334960 -0.909234          0    21984
# 4 -0.514431          0 -0.354547 -0.909234          0     3866
#
#    region_northwest  region_southeast  region_southwest  bmi_category_Normal  \
# 0                 0                 0                 1                    0
# 1                 0                 1                 0                    0
# 2                 0                 1                 0                    0
# 3                 1                 0                 0                    1
# 4                 1                 0                 0                    0
#
#    bmi_category_Overweight  bmi_category_Obese
# 0                        1                   0
# 1                        0                   1
# 2                        0                   1
# 3                        0                   0
# 4                        1                   0

# %%
from scipy.stats import pearsonr

# ----------------------------------
# Pearson Correlation Calculation
# ----------------------------------

# List of features to check against target
selected_features = [
    'age', 'bmi', 'children', 'is_female', 'is_smoker',
    'region_northwest', 'region_southeast', 'region_southwest',
    'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese'
]

correlations = {
    feature: pearsonr(df_cleaned[feature], df_cleaned['charges'])[0]
    for feature in selected_features
}
correlation_df = pd.DataFrame(list(correlations.items()), columns=['Feature', 'Pearson Correlation'])
correlation_df.sort_values(by='Pearson Correlation', ascending=False)
# Out:
#                     Feature  Pearson Correlation
# 4                 is_smoker             0.787234
# 0                       age             0.298309
# 10       bmi_category_Obese             0.200348
# 1                       bmi             0.196236
# 6          region_southeast             0.073577
# 2                  children             0.067390
# 5          region_northwest            -0.038695
# 7          region_southwest            -0.043637
# 3                 is_female            -0.058046
# 8       bmi_category_Normal            -0.104042
# 9   bmi_category_Overweight            -0.120601

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      1337 non-null   float64
#  1   is_female                1337 non-null   int64
#  2   bmi                      1337 non-null   float64
#  3   children                 1337 non-null   float64
#  4   is_smoker                1337 non-null   int64
#  5   charges                  1337 non-null   int64
#  6   region_northwest         1337 non-null   int64
#  7   region_southeast         1337 non-null   int64
#  8   region_southwest         1337 non-null   int64
#  9   bmi_category_Normal      1337 non-null   int64
#  10  bmi_category_Overweight  1337 non-null   int64
#  11  bmi_category_Obese       1337 non-null   int64
# dtypes: float64(3), int64(9)
# memory usage: 135.8 KB

# %%
cat_features = [
    'is_female', 'is_smoker',
    'region_northwest', 'region_southeast', 'region_southwest',
    'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese'
]

# %%
from scipy.stats import chi2_contingency

alpha = 0.05

df_cleaned['charges_bin'] = pd.qcut(df_cleaned['charges'],q=4,labels=False)
chi2_results = {}
for col in cat_features:
    contingency = pd.crosstab(df_cleaned[col], df_cleaned['charges_bin'])
    chi2_stat, p_val, _, _ = chi2_contingency(contingency)
    decision = 'Reject Null (Keep Feature)' if p_val < alpha else 'Accept Null (Drop Feature)'
    chi2_results[col] = {
        'chi2_statistic': chi2_stat,
        'p_value': p_val,
        'Decision': decision
    }
chi2_df = pd.DataFrame(chi2_results).T
chi2_df = chi2_df.sort_values(by='p_value')
chi2_df
# Out:
#                         chi2_statistic   p_value                    Decision
# is_smoker                   848.219178       0.0  Reject Null (Keep Feature)
# region_southeast             15.998167  0.001135  Reject Null (Keep Feature)
# is_female                    10.258784   0.01649  Reject Null (Keep Feature)
# bmi_category_Obese            8.515711  0.036473  Reject Null (Keep Feature)
# region_southwest              5.091893  0.165191  Accept Null (Drop Feature)
# bmi_category_Overweight        4.25149  0.235557  Accept Null (Drop Feature)
# bmi_category_Normal           3.708088   0.29476  Accept Null (Drop Feature)
# region_northwest               1.13424  0.768815  Accept Null (Drop Feature)

# %%
final_df = df_cleaned[['age', 'is_female', 'bmi', 'children', 'is_smoker', 'charges','region_southeast','bmi_category_Obese']]

# %%
final_df
# Out:
#            age  is_female       bmi  children  is_smoker  charges  \
# 0    -1.440418          1 -0.517949 -0.909234          1    16884
# 1    -1.511647          0  0.462463 -0.079442          0     1725
# 2    -0.799350          0  0.462463  1.580143          0     4449
# 3    -0.443201          0 -1.334960 -0.909234          0    21984
# 4    -0.514431          0 -0.354547 -0.909234          0     3866
# ...        ...        ...       ...       ...        ...      ...
# 1333  0.767704          0 -0.027743  1.580143          0    10600
# 1334 -1.511647          1  0.135659 -0.909234          0     2205
# 1335 -1.511647          1  0.952670 -0.909234          0     1629
# 1336 -1.297958          1 -0.844753 -0.909234          0     2007
# 1337  1.551231          1 -0.191145 -0.909234          1    29141
#
#       region_southeast  bmi_category_Obese
# 0                    0                   0
# 1                    1                   1
# 2                    1                   1
# 3                    0                   0
# 4                    0                   0
# ...                ...                 ...
# 1333                 0                   1
# 1334                 0                   1
# 1335                 1                   1
# 1336                 0                   0
# 1337                 0                   0
#
# [1337 rows x 8 columns]

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_df.drop('charges',axis=1)
y = final_df['charges']
y
# Out:
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
#         ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
# Name: charges, Length: 1337, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 7.92127799e+03,  4.92119238e+03,  1.44361661e+04,  3.18350564e+04,
#         8.67581266e+03,  1.31496370e+04,  2.96706500e+04,  1.35753225e+03,
#         1.11138061e+04,  9.75901566e+03,  1.09718507e+04,  3.19207448e+04,
#         3.11479922e+04,  1.64631895e+04,  1.01416669e+04,  8.32071774e+03,
#         5.33803897e+03,  3.20017531e+04,  3.02451537e+03,  3.68006468e+03,
#         4.66358966e+03,  2.83775977e+04,  1.37230536e+04,  2.91390286e+04,
#         1.63696719e+03,  3.35754124e+03,  3.02702168e+04,  1.04643485e+04,
#         3.81439504e+04,  6.26093661e+03,  8.68421714e+03,  4.67261206e+03,
#         1.48827212e+04,  3.29787548e+04,  1.28522387e+04,  1.13729648e+04,
#         6.49317738e+03,  1.46545355e+04,  5.70278112e+03,  6.47197814e+03,
#         7.63468132e+03,  4.11424169e+03,  1.49876798e+04,  2.71649620e+03,
#         1.67469930e+04,  8.67413824e+03,  1.19532777e+04,  5.79080420e+03,
#         4.33908669e+03,  3.47804556e+03,  1.06695638e+04,  7.27985186e+03,
#         1.86030397e+03,  1.09685100e+04,  3.43324887e+04,  7.73326364e+03,
#         5.43404300e+03,  7.77615084e+03,  5.32261166e+03,  3.04003005e+04,
#         1.30766602e+04,  2.56093011e+04,  3.57697452e+04,  7.04507501e+03,
#         7.61094600e+03,  9.80408370e+03,  3.33891829e+04,  2.86546633e+03,
#         3.18036599e+04,  2.81889846e+04,  3.51548667e+04,  5.45673688e+03,
#         2.69820685e+04,  9.79309534e+03,  1.37959121e+04,  1.32212049e+04,
#         7.14642745e+03,  8.64901312e+03,  1.04361481e+04,  4.36944180e+03,
#         8.63449632e+02,  1.03661281e+04,  3.96644647e+03,  2.53717095e+03,
#         1.76689812e+04,  5.71147023e+03,  1.07486323e+04,  4.66117199e+03,
#         1.44564423e+04,  1.25985468e+04,  4.19513166e+03,  3.93695324e+04,
#         5.10207363e+03,  7.22564301e+03,  1.57950116e+04,  1.45715982e+04,
#         1.04244426e+04,  1.20961562e+04,  9.84718578e+03, -4.16030371e+01,
#         1.19911976e+04,  3.87292794e+03,  1.05894648e+04,  2.90938927e+04,
#         2.17056183e+02,  8.29385037e+03,  1.44930553e+04,  1.35141779e+04,
#         1.52312928e+04,  7.63365345e+03,  1.43727878e+04,  3.62782889e+04,
#         3.05805092e+04,  3.44653712e+04,  3.55010071e+04,  6.76613957e+03,
#         1.47290206e+04,  2.92337899e+04,  8.79127368e+03,  5.80649696e+03,
#         6.63880682e+03,  1.06538710e+04,  2.87473549e+04,  4.72453671e+03,
#         2.30363685e+03,  1.49692929e+04,  6.52365091e+03,  7.74847606e+03,
#         1.05090065e+04,  1.17445996e+02,  2.67901147e+04,  5.19516049e+03,
#         6.12098888e+03,  6.69407217e+03,  9.06547862e+03,  1.20367173e+04,
#         1.10833326e+04,  6.54889445e+03,  9.55941420e+03,  4.97592936e+03,
#         6.84671630e+03,  2.95202901e+04,  9.37094813e+03,  1.46207213e+04,
#         1.57925804e+04,  9.26481463e+03,  4.53880656e+03,  6.37355644e+03,
#         4.18768531e+03,  1.24055651e+04])

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.7737291785851905

# %%
n = X_test.shape[0]
p = X_test.shape[1]

print(f'n: {n} and p: {p}')
# Out:
# n: 442 and p: 7

# %%
adjusted_r2 = 1 - ((1- r2) * (n-1) / (n - p - 1))
adjusted_r2
# Out:
# 0.7700796492075324
